# %% [markdown]
# <a href="https://colab.research.google.com/github/aviraj0622/aviraj/blob/main/Copy_of_Experiment_no_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
a=pd.read_csv("/content/Population dataset(2).csv")
a.head(20)
# Out:
#     Bodyweight
# 0        27.03
# 1        24.80
# 2        27.02
# 3        28.07
# 4        23.55
# 5        22.72
# 6        24.82
# 7        21.60
# 8        23.98
# 9        26.60
# 10       19.24
# 11       21.43
# 12       22.73
# 13       20.10
# 14       20.60
# 15       21.49
# 16       24.73
# 17       27.92
# 18       27.51
# 19       19.88

# %%
len(a)
# Out:
# 225

# %%
a.mean()
# Out:
# Bodyweight    23.893378
# dtype: float64

# %%
a.median()
# Out:
# Bodyweight    23.54
# dtype: float64

# %%
a.mode()
# Out:
#    Bodyweight
# 0       23.39
# 1       24.82
